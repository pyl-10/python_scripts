# %%
import requests
from time import sleep
from bs4 import BeautifulSoup

# 请求头
headers = {
    'accept':'text/html, application/xhtml+xml, application/xml; q=0.9, image/webp, */*; q=0.8',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Mobile Safari/537.36',
    'cookie': 'sessid=7ED31CA3-99CC-4D65-AB6C-1A6A517FEBD7; aQQ_ajkguid=685EFD4F-5C10-AE6C-1E83-FA2D840698D2; ctid=14; twe=2; id58=e87rkF/r3VCsRuWeEoakAg==; _ga=GA1.2.375895391.1609293136; _gid=GA1.2.2046575971.1609293136; wmda_uuid=c06703e97e504e52171244ed1903611a; wmda_new_uuid=1; wmda_session_id_6289197098934=1609293135662-910c0fd9-876b-1db0; wmda_visited_projects=%3B6289197098934; 58tj_uuid=a123ac24-3c00-4739-b090-16fd4de24cb9; init_refer=; new_uv=1; als=0; new_session=0; obtain_by=1'
}

with open('house.txt', 'a+') as f:
    for i in range(1, 11):
        url = 'https://beijing.anjuke.com/sale/p{}/'.format(str(i))
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, 'lxml')
        house_list = soup.find_all('li', class_='list-item')
        for house in house_list:
            name = house.find('div', class_='house-title').a.text.strip()
            price = house.find('span', class_='price-det').text.strip()
            area = house.find('span', class_='comm-address').text.strip()
            info = {
                'name': name,
                'price': price,
                'area': area
            }
            f.writelines(str(info))
            result = f.read()
            print(result)
# Out:
# {'name': '二期地暖两居室 户型方正 明厨明卫 钥匙房 澳洲', 'price': '1080万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '！阳光上东！洋房大两居，131平1100万，地暖房，观  。', 'price': '1100万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '朝阳公园 阳光上东 一层带   美洲通透两居 总价低 保养好', 'price': '1100万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '阳光上东 一层地暖两居 业主自住 看房预约 20平', 'price': '1090万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '地暖房中，总价第二低。08年澳洲组团，全落地窗，房间大的合理', 'price': '1100万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '阳光上东 精装2居室 总价低 可约看', 'price': '1200万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '莫得错过！美洲组团11号2居，带观景大阳台！大落地窗，有车位', 'price': '1195万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# {'name': '20平米   澳洲组团南北2居  地暖房 明厨明卫 全落地窗', 'price': '1090万', 'area': '阳光上东\xa0\xa0\n                    朝阳-酒仙桥-东四环北路6号'}
#
# ...

# %%
# 请求头
headers = {
    'accept':'text/html, application/xhtml+xml, application/xml; q=0.9, image/webp, */*; q=0.8',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Mobile Safari/537.36'
}
url = 'https://beijing.anjuke.com/sale/p1'
session = requests.session()
session.get(url, headers=headers)
cookie = session.cookies
print(cookie)
res = requests.get(url, headers=headers, cookies=cookie)
house_list = soup.find_all('li', class_='list-item')
print(house_list)
# Out:
# <RequestsCookieJar[<Cookie aQQ_ajkguid=7F9DEBD5-11E8-5563-B106-01356EB8BED6 for .anjuke.com/>, <Cookie ctid=14 for .anjuke.com/>, <Cookie obtain_by=2 for .anjuke.com/>, <Cookie sessid=09312FC1-4634-3A8F-365C-FA921B2B5354 for .anjuke.com/>, <Cookie twe=1 for .anjuke.com/>]>
# [<li class="list-item" data-from="">
# <div class="item-img">
# <img height="135" src="https://pic1.ajkimg.com/display/ajk/0785ad1051a2b3a2bbf9edc18b632ac0/214x156c.jpg?t=1" width="180"/>
# <div class="icon-wrapper">
# <img class="icon-video-new" src="https://pages.anjukestatic.com/usersite/site/img/common/esf_list_icon_shipin@3x.png"/>
# <img class="icon-720" src="https://pages.anjukestatic.com/usersite/site/img/common/esf_list_icon_quanjing@3x.png"/>
# </div>
# </div>
# <div class="house-details">
# <div class="house-title">
# ...

# %%
import requests
from time import sleep
from bs4 import BeautifulSoup
import csv

# 请求头
headers = {
    'accept':'text/html, application/xhtml+xml, application/xml; q=0.9, image/webp, */*; q=0.8',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Mobile Safari/537.36',
    'cookie': 'sessid=7ED31CA3-99CC-4D65-AB6C-1A6A517FEBD7; aQQ_ajkguid=685EFD4F-5C10-AE6C-1E83-FA2D840698D2; ctid=14; twe=2; id58=e87rkF/r3VCsRuWeEoakAg==; _ga=GA1.2.375895391.1609293136; _gid=GA1.2.2046575971.1609293136; wmda_uuid=c06703e97e504e52171244ed1903611a; wmda_new_uuid=1; wmda_session_id_6289197098934=1609293135662-910c0fd9-876b-1db0; wmda_visited_projects=%3B6289197098934; 58tj_uuid=a123ac24-3c00-4739-b090-16fd4de24cb9; init_refer=; new_uv=1; als=0; new_session=0; obtain_by=1'
}

with open('house.csv', 'a+', encoding='UTF-8', newline='') as f:
    for i in range(1, 11):
        url = 'https://beijing.anjuke.com/sale/p{}/'.format(str(i))
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, 'lxml')
        house_list = soup.find_all('li', class_='list-item')
        for house in house_list:
            name = house.find('div', class_='house-title').a.text.strip()
            price = house.find('span', class_='price-det').text.strip()
            area = house.find('span', class_='comm-address').text.strip()
            w = csv.writer(f)
            w.writerow((name, price, area))
            result = csv.reader(f)
#             print(result)

# %%
with open('house.csv', 'r', encoding='UTF-8') as csvfile:
    csv_reader = csv.reader(csvfile)
    print(csv_reader)
    for row in csv_reader:
        print(row)
# Out:
# ...
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ['name', 'price', 'area']
# ...

# %%
import requests
from bs4 import BeautifulSoup
import datetime
# 获取页面
def get_page(link):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'}
    r = requests.get(link, headers = headers)
    html = r.content  #使用r.content解封装
    html = html.decode('utf-8')  #由UTF-8解码为unicode
    soup = BeautifulSoup(html, 'lxml')
    return soup
# 解析网页
def get_data(post_list):
    data_list =[]
    for post in post_list:
        title =post.find('div', class_='titlelink box').text.strip()
        post_link = post.find('div', class_='titlelink box').a['href']
        post_link = "https://bbs.hupu.com" + post_link
        author =post.find('div', class_='author box').a.text.strip()
        author_page =post.find('div', class_='author box').a['href']
        start_date = post.find('div', class_='author box').contents[5].text.strip()
        reply_view = post.find('span', class_='ansour box').text.strip()
        reply = reply_view.split('/')[0].strip()
        view = reply_view.split('/')[1].strip()
        reply_time = post.find('div', class_='endreply box').a.text.strip()
        last_reply = post.find('div', class_='endreply box').span.text.strip()
        if ':' in reply_time:    #时间是11:27
            date_time = str(datetime.date.today()) + ' ' +reply_time
            date_time = datetime.datetime.strptime(date_time, '%Y-%m-%d %H:%M')
        elif reply_time.find("-") == 4: #时间是2017-02-27
            date_time = datetime.datetime.strptime(reply_time, '%Y-%m-%d').date()
        else: #时间是11-27
            date_time = datetime.datetime.strptime('2018-' +reply_time, '%Y-%m-%d').date()
            data_list.append([title, post_link, author, author_page,start_date, reply, view, last_reply, date_time])
    return data_list
        

post_all= soup.find('ul', class_="for-list")
post_list = post_all.find_all('li')
data_list = get_data(post_list)
for each in data_list:
    print (each)

# %%
import requests
from bs4 import BeautifulSoup
import datetime
# 获取页面
def get_page(link):
    headers = {
        'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6',
        'cookie': '176b1b73a9849d-017ad5c8853299-6d112d7c-1296000-176b1b73a9983%22%2C%22%24device_id%22%3A%22176b1b73a9849d-017ad5c8853299-6d112d7c-1296000-176b1b73a9983%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%7D; Hm_lvt_4fac77ceccb0cd4ad5ef1be46d740615=1609299344; Hm_lvt_b241fb65ecc2ccf4e7e3b9601c7a50de=1609299344; Hm_lvt_c324100ace03a4c61826ef5494c44048=1609299344; Hm_lpvt_c324100ace03a4c61826ef5494c44048=1609299344; csrfToken=drqpdKXgPm39Wb0tZ6Op5gJq; __gads=ID=3a3b4458bbe4cadd:T=1609299344:S=ALNI_Mb9ZTKJhLmqdNGH0hPQ9WHzcZ0wdw; smidV2=20201230113809881029eadb1ee4b01fd562db444dc16a00064912e4b087200; Hm_lpvt_4fac77ceccb0cd4ad5ef1be46d740615=1609299889; Hm_lpvt_b241fb65ecc2ccf4e7e3b9601c7a50de=1609299889; _HUPUSSOID=a862c3d7-91bd-4225-8bfc-235e956a88ff; _CLT=868ae16f150cf61ab926af24b4aa60be; u=85777995|6JmO5omRSlIyMDQ0OTc0Nzkz|153c|100b180bb990288a1b9189f5fea11105|b990288a1b9189f5|aHVwdV85OWRmNzkzYzQ1NTM0ZGFj; us=492a91f0c792108e803529eb917d5e25c028dddfdf882f07587db2342fe0947bc94877ce598068d91ac24737f60e994f444d3791119928bacf2d1d12216fb6a3; acw_tc=76b20f6916093147669684856e2b86257c4fb219c040d525650f97193d7da6; ua=16763696'
    }
    r = requests.get(link, headers = headers)
    html = r.content  #使用r.content解封装
    html = html.decode('utf-8')  #由UTF-8解码为unicode
    soup = BeautifulSoup(html, 'lxml')
    return soup

# 解析网页
def get_data(post_list):
    data_list =[]
    for post in post_list:
        title =post.find('div', class_='titlelink box').text.strip()
        post_link = post.find('div', class_='titlelink box').a['href']
        post_link = "https://bbs.hupu.com" + post_link
        author =post.find('div', class_='author box').a.text.strip()
        author_page =post.find('div', class_='author box').a['href']
        start_date = post.find('div', class_='author box').contents[5].text.strip()
        reply_view = post.find('span', class_='ansour box').text.strip()
        reply = reply_view.split('/')[0].strip()
        view = reply_view.split('/')[1].strip()
        reply_time = post.find('div', class_='endreply box').a.text.strip()
        last_reply = post.find('div', class_='endreply box').span.text.strip()
        if ':' in reply_time:    #时间是11:27
            date_time = str(datetime.date.today()) + ' ' +reply_time
            date_time = datetime.datetime.strptime(date_time, '%Y-%m-%d %H:%M')
        elif reply_time.find("-") == 4: #时间是2017-02-27
            date_time = datetime.datetime.strptime(reply_time, '%Y-%m-%d').date()
        else: #时间是11-27
            date_time = datetime.datetime.strptime('2018-' +reply_time, '%Y-%m-%d').date()
            data_list.append([title, post_link, author, author_page,start_date, reply, view, last_reply, date_time])
    return data_list

link = "https://bbs.hupu.com/bxj"
soup = get_page(link)
post_all= soup.find('ul', class_="for-list")
post_list = post_all.find_all('li')
# print(post_list)
data_list = get_data(post_list)
for each in data_list:
    print(each)

# %%
import tensorflow.compat.v1 as tf

g = tf.Graph()
with g.as_default():
    hello = tf.constant('hello tensorflow')
sess = tf.Session(graph=g)
omsg = sess.run(hello)
print(omsg)
# Out:
# b'hello tensorflow'

# %%
hello is tf.get_default_graph()
# Out:
# False

# %%
import tensorflow as tf

g = tf.Graph()
with g.as_default():
    a = tf.constant(1.0)
    b = tf.constant(1.0)
    op1 = tf.add(a, b)

with tf.compat.v1.Session(graph=g) as sess:
    m = sess.run(op1)
    print(m)
# Out:
# 2.0

# %%
import tensorflow as tf
hello = tf.constant('Hello, TensorFlow!')
tf.print(hello)
# Out:
# Hello, TensorFlow!

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
hello = tf.constant('Hello, TensorFlow!')
sess = tf.compat.v1.Session()
print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'

# %%
from __future__ import print_function

# 导入 MNIST 数据集
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-8584439caa66> in <module>
#       2
#       3 # 导入 MNIST 数据集
# ----> 4 from tensorflow.examples.tutorials.mnist import input_data
#       5 mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
#       6
#
# ModuleNotFoundError: No module named 'tensorflow.examples'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.0'

# %%
mint=tf.keras.datasets.mnist
(x_,y_),(x_1,y_1)=mint.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 8s 1us/step

# %%
import matplotlib.pyplot as plt
plt.imshow(x_[0], cmap="binary")
plt.show()

# %%
import urllib.robotparser as urobot
import requests

url = 'https://www.taobao.com/'
rp = urobot.RobotFileParser()
rp.set_url(url + '/robots.txt')
rp.read()
user_agent = 'Baiduspider'
if rp.can_fetch(user_agent, 'https://www.taobao.com/product/'):
    site = requests.get(url)
    print('seems good')
else:
    print('cannot scrap because robots.txt banned you')
# Out:
# cannot scrap because robots.txt banned you

# %%
import wad.detection

det = wad.detection.Detector()
url = input()
print(det.detect(url))
# Out:
# http://www.12306.cn/
# {'https://www.12306.cn/index/': [{'app': 'RequireJS', 'ver': None, 'type': 'JavaScript Frameworks'}, {'app': 'Handlebars', 'ver': None, 'type': 'JavaScript Frameworks'}]}

# %%
import pymysql.cursors
import requests
from bs4 import BeautifulSoup
import arrow

urls = [u'https://news.so.com/ns?q=北京&pn={}']
for i, url in enumerate(urls):
    r = requests.get(url)
    bs = BeautifulSoup(r.text)
    items = bs.find_all('a', class_='news_title')
    t_list = []
    for one in items:
        t_item = []
        if '360' in one.get('href'):
            continue
        t_item.append(one.get('href'))
        connection = pymysql.connect()
        try:
            with connection.cursor() as cursor:
                for one in t_list:
                    try:
                        sql_q = "insert into 'newspost' ('post_title', 'post_url', 'news_postdate') values (%s, %s, %s)"
                        cursor.execute(sql_q, (one[1], one[0], one[2]))
                    except pymysql.err.IntegrityError as e:
                        print(e)
                        continue
                connection.commit()
            finally:
                connection.close()

# %%
import json, requests
API_KEY = ''
def getGeo(add):
    add = str(add).replace(' ', '+')
    quiry = \
        'https://maps.googleapis.com/maps/api/geocode/' \
        'json?address={}&key={}' \
        .format(add, API_KEY)
    res = requests.get(quiry)
    j = json.loads(res.text)
    return j.get('results')[0].get('geometry').get('viewport').get('southwest').values()

# %%
import re

strValue = 'aaaabbb1234'
# data = re.compile(r'(\w)', strValue)
# data
# data = re.match(r'\d+', strValue)
# data.group()
data = re.findall(r'\d+', strValue)
data
data2 = re.sub(r'\d+', '123', strValue)
data2
# Out:
# 'aaaabbb123'

# %%
reg = re.compile(r'\d+')
data = reg.search(strValue)
print(data.group())
# Out:
# 1234

# %%
import csv
import pickle

tlist = [1, 2, 4, 33]
with open('tlist.txt', 'ab') as t:
    pickle.dump(tlist, t)
    
with open('tlist.txt', 'rb') as t:
    t2 = pickle.load(t)
    print(t2)
# Out:
# [1, 2, 4, 33]

# %%
from PIL import Image, ImageFilter

img = Image.open()
img.show()
img.size
img.format
img.save()

# %%
import collections
Card = collections.namedtuple('Card', ['rank', 'suit'])
class FrenchDeck:
    ranks = [str(n) for n in range(2, 11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()
    def __init__(self):
        self.cards = [Card(rank, suit) for suit in self.suits
                     for rank in self.ranks]
    def __len__(self):
        return len(self._cards)
    def __getitem__(self, position):
        return self.cards[position]

# %%
beer_card = Card('7','diamonds')
len(beer_card)
# Out:
# 2
