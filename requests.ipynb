# %%
from selenium import webdriver

# %%
driver = webdriver.Firefox(executable_path='/Users/xing_zhi/opt/miniconda3/bin/geckodriver')
driver.get('http://www.santostang.com/2018/07/04/hello-world')
driver.page_source
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-35fd19d2a13e> in <module>
#       1 driver = webdriver.Firefox(executable_path='/Users/xing_zhi/opt/miniconda3/bin/geckodriver')
# ----> 2 driver.get('http://www.santostang.com/2018/07/04/hello-world')
#       3 driver.page_source
#
# ~/opt/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/opt/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
driver.page_source
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-7-7b1fd3841aad> in <module>
# ----> 1 driver.page_source
#
# ~/opt/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/opt/miniconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ...

# %%
from selenium import webdriver
fp = webdriver.FirefoxProfile()
fp.set_preference('permissions.default.stylesheet',2)
driver = webdriver.Firefox(firefox_profile=fp, executable_path=r'/Users/xing_zhi/opt/miniconda3/bin/geckodriver')
driver.get('http://www.santostang.com/2018/07/04/hello-world')

# %%
print(r'hello\World\npython')
# Out:
# hello\World\npython

# %%
import re
string = r'2\7'
m = re.match('(\d+)\\\\', string)
print(m)
print(m.group(1))
# Out:
# <re.Match object; span=(0, 2), match='2\\'>
# 2

# %%
string = r'2\7'
n = re.match('(\d+)\\', string )
print(n)
# Out:
# <re.Match object; span=(0, 2), match='2\\'>

# %%
import re 
m_match = re.match('com', 'www.santostang.com')
m_search = re.search('com', 'www.santostang.com')
print(m_match)
print(m_search)
# Out:
# None
# <re.Match object; span=(15, 18), match='com'>

# %%
import re 
m_match = re.match('[0-9]+','12345 is the first number,23456 is the sencond')
m_search = re.search('[0-9]+','the first number is 12345,23456 is the sencond')
m_findall = re.findall('[0-9]+','12345 is the first number,23456 is the sencond')
print(m_match.group())
print(m_search.group())
print(m_findall)
# Out:
# 12345
# 12345
# ['12345', '23456']

# %%
from bs4 import BeautifulSoup
import requests

link = 'http://www.santostang.com/'
# 请求头
headers = {
    'accept':'text/html, application/xhtml+xml, application/xml; q=0.9, image/webp, */*; q=0.8',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.67 Mobile Safari/537.36'
}
res = requests.get(link, headers=headers)
soup = BeautifulSoup(res.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <title>
#    Santos Tang
#   </title>
#   <meta content="Python网络爬虫：从入门到实践 官方网站及个人博客" name="description"/>
#   <meta content="Python网络爬虫, Python爬虫, Python, 爬虫, 数据科学, 数据挖掘, 数据分析, santostang, Santos Tang, 唐松, Song Tang" name="keywords"/>
#   <link href="http://www.santostang.com/wp-content/themes/SongStyle-Two/images/icon_32.png" rel="apple-touch-icon"/>
#   <link href="http://www.santostang.com/wp-content/themes/SongStyle-Two/images/icon_152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="http://www.santostang.com/wp-content/themes/SongStyle-Two/images/icon_167.png" rel="apple-touch-icon" sizes="167x167"/>
#   <link href="http://www.santostang.com/wp-content/themes/SongStyle-Two/images/icon_180.png" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
soup.header.h1
# Out:
# <h1 id="name">Santos Tang</h1>

# %%
soup.header.div.contents
# Out:
# [<a href="http://www.santostang.com" title="Santos Tang"><img alt="Santos Tang" class="img-circle" src="http://www.santostang.com/wp-content/uploads/2019/06/me.jpg" width="50%"/></a>]

# %%
for child in soup.header.div.children:
    print(child)
# Out:
# <a href="http://www.santostang.com" title="Santos Tang"><img alt="Santos Tang" class="img-circle" src="http://www.santostang.com/wp-content/uploads/2019/06/me.jpg" width="50%"/></a>

# %%
a_tag = soup.header.div.a
a_tag.parent
# Out:
# <div class="avatar"><a href="http://www.santostang.com" title="Santos Tang"><img alt="Santos Tang" class="img-circle" src="http://www.santostang.com/wp-content/uploads/2019/06/me.jpg" width="50%"/></a></div>

# %%
import pandas

# %%
with open('one', 'w') as tw:
    tw.read()

# %%
data = np.loadtxt(filename)[x**2 for x in range(-10, 11)]

# %%
* One
    - Sublist
        - This
  - Sublist
        - That
        - The other thing
* Two
  - Sublist
* Three
  - Sublist

# %%
import requests
import re

r = requests.get('https://static1.scrape.cuiqingcai.com')
pattern = re.compile('<h2.*?>(.*?)</h2>', re.S)
titles = re.findall(pattern, r.text)
print(titles)
# Out:
# ['霸王别姬 - Farewell My Concubine', '这个杀手不太冷 - Léon', '肖申克的救赎 - The Shawshank Redemption', '泰坦尼克号 - Titanic', '罗马假日 - Roman Holiday', '唐伯虎点秋香 - Flirting Scholar', '乱世佳人 - Gone with the Wind', '喜剧之王 - The King of Comedy', '楚门的世界 - The Truman Show', '狮子王 - The Lion King']

# %%
import requests

r = requests.get('https://github.com/favicon.ico')
print(r.text)
print(r.content)
# Out:
# :�������OL������������������!������4@���8���
# ���������������������������������������������������%   ������������va������G������������G+++������]I������+++������3������ �����5+*������&!����� �����f@@@b����������l+++R�����$$$��������������������������$$$ ������������������������ .����������������������. �������������������� $$$������������������$$$ �������������� +++G��������G+++
# ...

# %%
import requests

r = requests.get('https://github.com/favicon.ico')
with open('favicon.ico', 'wb') as f:
    f.write(r.content)

# %%
import requests
data = {
    'name':'germey',
    'age':'25'
}
r = requests.post('http://httpbin.org/post', data=data)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "25",
#     "name": "germey"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Content-Length": "18",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-5fd6d051-648e7c8448cf40c301402b5d"
#   },
#   "json": null,
#   "origin": "117.45.204.199",
#   "url": "http://httpbin.org/post"
# }

# %%
import requests

r = requests.get('https://static1.scrape.cuiqingcai.com')
print(type(r.status_code), r.status_code)
print(type(r.headers), r.headers)
print(type(r.cookies), r.cookies)
print(type(r.url), r.url)
print(type(r.history), r.history)
# Out:
# <class 'int'> 200
# <class 'requests.structures.CaseInsensitiveDict'> {'Date': 'Mon, 14 Dec 2020 02:41:58 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '41538', 'Connection': 'keep-alive', 'X-Frame-Options': 'DENY', 'X-Content-Type-Options': 'nosniff', 'Expires': 'Mon, 14 Dec 2020 02:50:44 GMT', 'Cache-Control': 'max-age=600', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains'}
# <class 'requests.cookies.RequestsCookieJar'> <RequestsCookieJar[]>
# <class 'str'> https://static1.scrape.cuiqingcai.com/
# <class 'list'> []

# %%
import requests

r = requests.get('https://static1.scrape.cuiqingcai.com')
exit() if not r.status_code == requests.codes.ok else print('Request Success')
# Out:
# Request Success

# %%
import requests

r = requests.get('https://static1.scrape.cuiqingcai.com')
print('ok') if not r.status_code == requests.codes.not_found else print('Request not found')
# Out:
# ok

# %%
import requests
files = {
    'file':open('favicon.ico', 'rb')
}

r = requests.post('http://httpbin.org/post', files=files)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "data:application/octet-stream;base64,..."
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Content-Length": "6665",
#     "Content-Type": "multipart/form-data; boundary=0481d7f820712606a399207c885fd43a",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-5fd6d335-2239ac6841f9dce0370f114c"
#   },
#   "json": null,
#   "origin": "117.45.204.199",
#   "url": "http://httpbin.org/post"
# }

# %%
import requests

r = requests.get('http://www.baidu.com')
print(r.cookies)
for key, value in r.cookies.items():
    print(key + '=' + value)
# Out:
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>
# BDORZ=27315

# %%
import requests

headers = {
    'Cookie':'_octo=GH1.1.1683558520.1605155110; _device_id=6ee9db3558b7734b86d7823ee9a9b5e1; tz=Asia%2FShanghai; user_session=nL1GyB7_m3AvLww6PFaHGO-scf1NbId0tBVRRZKOt_4fzX6-; __Host-user_session_same_site=nL1GyB7_m3AvLww6PFaHGO-scf1NbId0tBVRRZKOt_4fzX6-; tz=Asia%2FShanghai; logged_in=yes; dotcom_user=0Ichirin1; _gh_sess=DKk%2FCrbQZNix19caIOy23C3oJ3DsjKqme81PcK0wj5LOwVA9dpxSxJiHmJiQt4laHK1BtYuOU3kY7kvPEUUbSZjxMP4uwjCwTazmEbtYiuKlK2UqgFstKwGXggE58rhMVczFDyOHV5Yk9Llt8C%2F3LuSsmBz91jiPaisJWHtY7VYlYHCfDIJDbjZMuDmt%2BGCPg9%2F4YRitvEabNeD%2FezQA7MowBCGHlE2qBqgfCamztLjcTFfwFE7BB9F5NvUNsbSvPK3ITOHhUGsZG36cn9NjeMMG%2FID98Fz715tlJPCMbiniSlMJ20esoQo%2B2MWBbvRvwWBlImHRvZ3NowTwQU2MIICMDDMvgNr%2FnOlajtpy%2Bg6oURH%2BsJXwU%2B1QH3IvQwEIFPM3oNoAE6xjTsKWLIdL3EDJbXNjNVXUDzu%2BNQZV8S8Py7sp8Gajj9Daj%2B5nXRQcTOZ6cW89etgFrSWeYoUXD731CH2bcnrXLydBnulqQPmXektDKOrcMrnbNyaj6ikOcXy%2FbfZUIdB2GJFVN%2B%2F6ldw8sZC1Vq7bc3ykAqdICxobvaIZav3scncsGB3KXUE1ZqV0Ov%2BfZzv1MRvikY5oNHfBtq2AwMov970ZXOYwakpmeAK17VwAcb1FaGb3Tth04uxboQ5ZISTF99b%2FP7%2FLassXSg62Nr%2Ffdqnr1RTMxU
BHPcRAmrTke6jh2ADWDHzVCVnA%2BcT5Dzr4qcio5b0GxjLTSfqkRW39qMAAxKtQ7VCX0dN%2BpF9bthKtH3nW%2F5kZRyw0AB0AlV7QeDiN5SgbcPQKZ4N9cGQ1RNCqcDubOACNJiUkvROVnAGw%2F5x9%2Bpn0q%2FIVNgkUZ4Zt0APsQ8BvyQN1TTbqbQS6QI%2FSCyScWcgUaBUUTWZXn7Ry2IJ5%2Fyj73l7Nmi67s9DhjtUFTCUNmujwF6PhcisxxWAbLwqQ0PEF9--LFPIanNKE98SrSpP--YwDr1HQWuQLmVz1645AbIg%3D%3D'

jar = requests.cookies.RequestsCookieJar()
    
headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'   
}

for cookie in cookies.split(';'):
    key, value = cookie.split('=', 1)
    jar.set(key, value)
r = requests.get('https://github.com/', cookies=jar, headers=headers)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" data-color-mode="light">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-iNnUjxnDZbx2GqneSSzGFrvmlaN/BjrGF5q/p8z9Fa0/c+MsD+geqNbi5m2pBphVcQ4hV3yIWFLvyreiyDwvkQ==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-color-modes-88d9d48f19c365bc761aa9de492cc616.css" />
#
# ...

# %%
import requests
requests.get('http://httpbin.org/cookies/set/number/123456789')
r = requests.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {}
# }

# %%
import requests
s = requests.Session()
s.get('http://httpbin.org/cookies/set/number/123456789')
r = s.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {
#     "number": "123456789"
#   }
# }

# %%
import requests

res = requests.get('https://static2.scrape.cuiqingcai.com/')
print(res.status_code)
# Out:
# --------------------------------------------------------------------------
# SSLCertVerificationError                 Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
import requests

res = requests.get('https://static2.scrape.cuiqingcai.com/', verify=False)
print(res.status_code)
# Out:
# 500
# /Users/xing_zhi/opt/miniconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'static2.scrape.cuiqingcai.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import requests
from requests.packages import urllib3

urllib3.disable_warnings()
res = requests.get('https://static2.scrape.cuiqingcai.com/', verify=False)
print(res.status_code)
# Out:
# 500

# %%
import logging
import requests
logging.captureWarnings(True)
res = requests.get('https://static2.scrape.cuiqingcai.com/', verify = False)
print(res.status_code)
# Out:
# 500

# %%
import requests

r = requests.get('https://httpbin.org/get', timeout=(5, 30)) # connect 5秒以上为超时，read 30秒以上为超时 
print(r.status_code)
# Out:
# 200

# %%
import requests
from requests.auth import HTTPBasicAuth

r = requests.get('https://static3.scrape.cuiqingcai.com/', auth=HTTPBasicAuth('admin', 'admin'))
print(r.status_code)
# Out:
# 500

# %%
import requests

r = requests.get('https://static3.scrape.cuiqingcai.com/', auth=('admin', 'admin'))
print(r.status_code)
# Out:
# 500

# %%
import requests
from requests_oauthlib import OAuth1
url = 'https://api.tweitter.com/1.1/account/verify_credentials.json'
auth = OAuth1('YOUR_APP_KEY', 'YOUR_APP_SECRET', 'USER_OAUTH_TOKEN', 'USER_OAUTH_TOKEN_SECRET')
res = requests.get(url, auth=auth)
print(res.status_code)
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-33-269313764784> in <module>
#       3 url = 'https://api.tweitter.com/1.1/account/verify_credentials.json'
#       4 auth = OAuth1('YOUR_APP_KEY', 'YOUR_APP_SECRET', 'USER_OAUTH_TOKEN', 'USER_OAUTH_TOKEN_SECRET')
# ----> 5 res = requests.get(url, auth=auth)
#       6 print(res.status_code)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/miniconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
# ...

# %%
import requests
proxies = {
    'http':'http://10.10.10.10:1080',
    'https':'http://10.10.10.10:1080',
}
requests.get('https://httpbin.org/get', proxies=proxies)

# %%
from requests import Request, Session
url = 'http://httpbin.org/post'
data = {'name':'germey'}
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
s = Session()
req = Request('POST', url, data=data, headers=headers)
prepped = s.prepare_request(req)
r = s.send(prepped)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "name": "germey"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Content-Length": "11",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-5fd6e2d0-0e0f7a6f735ff8836d9b6fa9"
#   },
#   "json": null,
#   "origin": "117.45.204.199",
#   "url": "http://httpbin.org/post"
# }
