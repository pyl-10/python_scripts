# %%
'alice' * 5
# Out:
# 'alicealicealicealicealice'

# %%
import pygame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-671b35b41eba> in <module>
# ----> 1 import pygame
#
# ModuleNotFoundError: No module named 'pygame'

# %%
8-2
# Out:
# 6

# %%
43<100
# Out:
# True

# %%
if name == 'mary':
    print('hello mary')
if password == 'sword':
    print('')
else:
    print('')
